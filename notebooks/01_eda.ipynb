# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)
# ## Jobs in Data - Salary Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Config
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Load Data

# %%
import sys
sys.path.append('..')

from src.data.load_data import download_kaggle_data, load_raw_data

# Download data (first time only)
# path = download_kaggle_data()

# Load data
# df = load_raw_data('path/to/jobs_in_data.csv')

# %% [markdown]
# ## 2. Data Overview

# %%
# df.head()

# %%
# df.info()

# %%
# df.describe()

# %% [markdown]
# ## 3. Missing Values

# %%
# df.isnull().sum()

# %% [markdown]
# ## 4. Distribution Analysis

# %%
# Salary distribution
# plt.figure(figsize=(10, 6))
# sns.histplot(df['salary_in_usd'], kde=True)
# plt.title('Salary Distribution in Data Jobs')
# plt.xlabel('Salary (USD)')
# plt.savefig('../outputs/figures/salary_distribution.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 5. Correlation Analysis

# %%
# Correlation heatmap
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm')
# plt.title('Correlation Matrix')
# plt.savefig('../outputs/figures/correlation_matrix.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 6. Key Insights
#
# _(Document insights here)_
